# %% [markdown]
# # Final Project

# %% [markdown]
# Yihang Sun

# %% [markdown]
# # Introduction:

# %% [markdown]
# Gun control is more controversial than other countries in the United States. The United States has the highest homicide-by-firearm rate in developed countries. Gun violence cause tens of thousands of deaths and injuries annually. The problem of gun control is being a very disputed problem in the United States. Proponents of gun control think that limiting guns will save lives and reduce crime, but opponents think that it can help law-abiding citizens to defend themselves and against criminals.
#
# So I would find related data and analyze the problem of gun violence in the final project. This project also explore the most important factors in gun violence.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data to be Used:
# 1.I use the data 'More Guns, Less Crime?' from R Data Sets.It includes 1173 rows and 13 columns.This data will use csv format.
#
# 2.Another source is scraping of a web page from https://everytownresearch.org/report/gun-violence-in-america/.

# %% [markdown]
# # The data acquired and explored

# %% [markdown]
# # For the web page from https://everytownresearch.org/report/gun-violence-in-america/.
# I used the Data Miner to scraping.
# page scrape>>Select a Recipe>>Generic Recipe - Get Table Data>>scrape>> Download CSV file.

# %%
b=pd.read_csv('https://raw.githubusercontent.com/YihangSun123/AIM-5001/master/AIM-5001/The%20U.S.%20gun%20homicide%20rate%20is%2025%20times%20that%20of%20other%20high-income%20countries..csv')
b
# Out:
#           category  value
# 0    United States    4.1
# 1            Chile    1.9
# 2           Israel    0.7
# 3           Canada    0.3
# 4           Sweden    0.3
# 5            Italy    0.3
# 6      Switzerland    0.2
# 7          Finland    0.2
# 8  Slovak Republic    0.2

# %% [markdown]
# Converting From Long to Wide Format

# %%
#Converting From Long to Wide Format
b.pivot(columns='category', values='value')
# Out:
# category  Canada  Chile  Finland  Israel  Italy  Slovak Republic  Sweden  \
# 0            NaN    NaN      NaN     NaN    NaN              NaN     NaN
# 1            NaN    1.9      NaN     NaN    NaN              NaN     NaN
# 2            NaN    NaN      NaN     0.7    NaN              NaN     NaN
# 3            0.3    NaN      NaN     NaN    NaN              NaN     NaN
# 4            NaN    NaN      NaN     NaN    NaN              NaN     0.3
# 5            NaN    NaN      NaN     NaN    0.3              NaN     NaN
# 6            NaN    NaN      NaN     NaN    NaN              NaN     NaN
# 7            NaN    NaN      0.2     NaN    NaN              NaN     NaN
# 8            NaN    NaN      NaN     NaN    NaN              0.2     NaN
#
# category  Switzerland  United States
# 0                 NaN            4.1
# 1                 NaN            NaN
# 2                 NaN            NaN
# 3                 NaN            NaN
# 4                 NaN            NaN
# ...

# %%
b1=pd.read_csv('https://raw.githubusercontent.com/YihangSun123/AIM-5001/master/AIM-5001/Firearms%20are%20the%20leading%20cause%20of%20death%20for%20American%20children%20and%20teens.%20(1).csv')
b1
# Out:
#         category  value
# 0      Poisoning    947
# 1    Suffocation   1646
# 2         Cancer   1790
# 3  Motor Vehicle   3314
# 4        Firearm   3335

# %% [markdown]
# These two data show that why the problem of Gun violence is very improtant, and why the law of gun control is being a controversial topic.

# %% [markdown]
# # For the data 'More Guns, Less Crime?' from R Data Sets, using the pd.read

# %%
#reading data
data=pd.read_csv('https://raw.githubusercontent.com/YihangSun123/AIM-5001/master/AIM-5001/Guns%20(5).csv')
data
# Out:
#       Unnamed: 0  year  violent  murder  robbery  prisoners      afam  \
# 0              1  1977    414.4    14.2     96.8         83  8.384873
# 1              2  1978    419.1    13.3     99.1         94  8.352101
# 2              3  1979    413.3    13.2    109.5        144  8.329575
# 3              4  1980    448.5    13.2    132.1        141  8.408386
# 4              5  1981    470.5    11.9    126.5        149  8.483435
# ...          ...   ...      ...     ...      ...        ...       ...
# 1168        1169  1995    254.2     2.1     17.9        254  1.485849
# 1169        1170  1996    249.7     3.3     20.4        289  1.521814
# 1170        1171  1997    255.2     3.5     17.7        310  1.527818
# 1171        1172  1998    247.6     4.8     16.2        326  1.558396
# 1172        1173  1999    232.3     2.3     15.4        327  1.613004
#
#           cauc      male  population     income   density    state  law
# ...

# %%
# delete the column 'Unnamed: 0'
a=data.drop(columns=['Unnamed: 0'])
a
# Out:
#       year  violent  murder  robbery  prisoners      afam      cauc      male  \
# 0     1977    414.4    14.2     96.8         83  8.384873  55.12291  18.17441
# 1     1978    419.1    13.3     99.1         94  8.352101  55.14367  17.99408
# 2     1979    413.3    13.2    109.5        144  8.329575  55.13586  17.83934
# 3     1980    448.5    13.2    132.1        141  8.408386  54.91259  17.73420
# 4     1981    470.5    11.9    126.5        149  8.483435  54.92513  17.67372
# ...    ...      ...     ...      ...        ...       ...       ...       ...
# 1168  1995    254.2     2.1     17.9        254  1.485849  73.71621  15.37098
# 1169  1996    249.7     3.3     20.4        289  1.521814  73.85796  15.44601
# 1170  1997    255.2     3.5     17.7        310  1.527818  73.92731  15.49400
# 1171  1998    247.6     4.8     16.2        326  1.558396  73.98515  15.51021
# 1172  1999    232.3     2.3     15.4        327  1.613004  74.04952  15.48013
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
grouped = a['state'].groupby(a['violent'])

# display summary statistics for the groupings
grouped.describe()
# Out:
#         count unique                   top freq
# violent
# 47.0        1      1          North Dakota    1
# 51.3        1      1          North Dakota    1
# 53.6        1      1          North Dakota    1
# 53.7        1      1          North Dakota    1
# 54.0        1      1          North Dakota    1
# ...       ...    ...                   ...  ...
# 2469.8      1      1  District of Columbia    1
# 2661.4      1      1  District of Columbia    1
# 2662.6      1      1  District of Columbia    1
# 2832.8      1      1  District of Columbia    1
# 2921.8      1      1  District of Columbia    1
#
# [1101 rows x 4 columns]

# %%
new_df = a[["year", "violent", "income"]]
new_df
# Out:
#       year  violent     income
# 0     1977    414.4   9563.148
# 1     1978    419.1   9932.000
# 2     1979    413.3   9877.028
# 3     1980    448.5   9541.428
# 4     1981    470.5   9548.351
# ...    ...      ...        ...
# 1168  1995    254.2  14070.160
# 1169  1996    249.7  14032.230
# 1170  1997    255.2  14790.980
# 1171  1998    247.6  15225.510
# 1172  1999    232.3  15765.070
#
# [1173 rows x 3 columns]

# %%
a[a["state"] == 'Alabama']
# Out:
#     year  violent  murder  robbery  prisoners      afam      cauc      male  \
# 0   1977    414.4    14.2     96.8         83  8.384873  55.12291  18.17441
# 1   1978    419.1    13.3     99.1         94  8.352101  55.14367  17.99408
# 2   1979    413.3    13.2    109.5        144  8.329575  55.13586  17.83934
# 3   1980    448.5    13.2    132.1        141  8.408386  54.91259  17.73420
# 4   1981    470.5    11.9    126.5        149  8.483435  54.92513  17.67372
# 5   1982    447.7    10.6    112.0        183  8.514000  54.89621  17.51052
# 6   1983    416.0     9.2     98.4        215  8.545608  54.83936  17.35089
# 7   1984    431.2     9.4     96.1        243  8.559511  54.77876  17.11902
# 8   1985    457.5     9.8    105.4        256  8.562801  54.67899  16.85875
# 9   1986    558.0    10.1    111.6        267  8.566521  54.51791  16.57609
# 10  1987    559.2     9.3    112.2        283  8.592103  54.38770  16.28230
# ...

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # map is a difficult challenge

# %%
import plotly.graph_objects as go
import pandas as pd

df =x1 #read data table
#fig
fig = go.Figure(data = go.Choropleth(
    locations=df['state'],#read state
    z=df['income'].astype(float),#
    locationmode='USA-states',#fig location
    colorscale='Reds',#color
    colorbar_title="violent",
    hovertext=df['state'],#show state name
))

fig.update_layout(
    title_text = 'Us violent', # title 
    geo_scope = 'usa'#format
 #scope select"world"，"usa"，"europe"，"asia"，"africa"，"north america"，"south america" 
)


#show fig
fig.show()
# Out:
# <div>                            <div id="7eef565c-881c-4374-87ed-e7dedea34020" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7eef565c-881c-4374-87ed-e7dedea34020")) {                    Plotly.newPlot(                        "7eef565c-881c-4374-87ed-e7dedea34020",                        [{"colorbar": {"title": {"text": "violent"}}, "colorscale": [[0.0, "rgb(255,245,240)"], [0.125, "rgb(254,224,210)"], [0.25, "rgb(252,187,161)"], [0.375, "rgb(252,146,114)"], [0.5, "rgb(251,106,74)"], [0.625, "rgb(239,59,44)"], [0.75, "rgb(203,24,29)"], [0.875, "rgb(165,15,21)"], [1.0, "rgb(103,0,13)"]], "hovertext": ["Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware", "District of Columbia", "Florida", "Georgia", "Hawai
# ...

# %% [markdown]
# # The data includes 1977-1999, and I only use the 1999's data because it is close to now

# %%
#extracting the 1999's data
x1=a.loc[a["year"]==1999,]
x1
# Out:
#       year  violent  murder  robbery  prisoners       afam      cauc  \
# 22    1999    490.2     7.9    121.2        519   9.331416  55.29781
# 45    1999    631.5     8.6     91.4        413   8.986603  60.55464
# 68    1999    551.2     8.0    152.5        507   4.343524  63.80436
# 91    1999    425.2     5.6     79.3        415   5.961927  61.21140
# 114   1999    627.2     6.0    181.1        483   8.089670  58.14976
# 137   1999    340.5     4.6     75.3        357   3.094968  71.19784
# 160   1999    345.6     3.3    123.5        372   4.480762  64.13895
# 183   1999    734.0     3.2    197.9        429   8.134692  58.07962
# 206   1999   1627.7    46.4    644.3       1913  21.669750  29.27457
# 229   1999    854.0     5.7    211.6        447   6.394272  57.11421
# 252   1999    534.0     7.5    166.4        502  11.108590  53.18856
# 275   1999    235.0     3.7     88.1        307  24.163870  26.08433
# 298   1999    244.9     2.0     17.8        330   1.250619  73.22482
# ...

# %% [markdown]
# # Income fact

# %%
# USing scatterplot to analyze the relationship between income and violent
sns.scatterplot( data=a, x='income', y='violent')
# Out:
# <AxesSubplot:xlabel='income', ylabel='violent'>

# %% [markdown]
# The income fact can affect violent because high income people usually become victim of gun violent easily.
# For equal level income, low violent states are more than high violent states, so the influence of income is not large.

# %% [markdown]
# # Race fact

# %%
# USing scatterplot to analyze the relationship between cauc and violent
sns.scatterplot( data=a, x='cauc', y='violent')
# Out:
# <AxesSubplot:xlabel='cauc', ylabel='violent'>

# %%
# USing scatterplot to analyze the relationship between afam and violent
sns.scatterplot( data=a, x='afam', y='violent')
# Out:
# <AxesSubplot:xlabel='afam', ylabel='violent'>

# %% [markdown]
# For these two scatterplots, they show most high afam states and most low cauc states have have high violent although some states are not.
# The race fact has a relative high influence.

# %% [markdown]
# # year facts

# %% [markdown]
# For the year fact, I choose two state to analyze the year fact. They are Alabama and North Carolina.

# %%
#extracting Alabama's data
x2=a.loc[a["state"]=='Alabama',]
x2
# Out:
#     year  violent  murder  robbery  prisoners      afam      cauc      male  \
# 0   1977    414.4    14.2     96.8         83  8.384873  55.12291  18.17441
# 1   1978    419.1    13.3     99.1         94  8.352101  55.14367  17.99408
# 2   1979    413.3    13.2    109.5        144  8.329575  55.13586  17.83934
# 3   1980    448.5    13.2    132.1        141  8.408386  54.91259  17.73420
# 4   1981    470.5    11.9    126.5        149  8.483435  54.92513  17.67372
# 5   1982    447.7    10.6    112.0        183  8.514000  54.89621  17.51052
# 6   1983    416.0     9.2     98.4        215  8.545608  54.83936  17.35089
# 7   1984    431.2     9.4     96.1        243  8.559511  54.77876  17.11902
# 8   1985    457.5     9.8    105.4        256  8.562801  54.67899  16.85875
# 9   1986    558.0    10.1    111.6        267  8.566521  54.51791  16.57609
# 10  1987    559.2     9.3    112.2        283  8.592103  54.38770  16.28230
# ...

# %%
# USing lineplot to analyze the relationship between year and violent
sns.lineplot( data=x2, x='year', y='violent')
# Out:
# <AxesSubplot:xlabel='year', ylabel='violent'>

# %%
#extracting North Carolina's data
x3=a.loc[a["state"]=='North Carolina',]
x3
# Out:
#      year  violent  murder  robbery  prisoners      afam      cauc      male  \
# 759  1977    407.1    10.6     61.3        214  8.210358  57.76085  18.84295
# 760  1978    413.4    10.8     65.9        234  8.235327  57.72733  18.67500
# 761  1979    446.1    10.7     77.2        223  8.260472  57.66654  18.47252
# 762  1980    455.0    10.6     82.3        240  8.406182  57.73013  18.44014
# 763  1981    436.7     9.1     80.8        244  8.458397  57.83779  18.39927
# 764  1982    446.3     9.1     85.9        248  8.458483  57.81456  18.22489
# 765  1983    409.6     8.1     79.6        255  8.469481  57.71644  18.07053
# 766  1984    403.6     8.7     74.8        233  8.468751  57.70063  17.83964
# 767  1985    420.9     8.3     78.2        246  8.461959  57.61550  17.60892
# 768  1986    475.9     8.1     87.7        254  8.427985  57.37815  17.24389
# 769  1987    484.0     8.1     93.9        257  8.427617  57.17760  16.91528
# ...

# %%
# USing lineplot to analyze the relationship between year and violent
sns.lineplot( data=x3, x='year', y='violent')
# Out:
# <AxesSubplot:xlabel='year', ylabel='violent'>

# %% [markdown]
# For these two lineplot, we can know that the violent was incresed from 1977 to about 1992, and then it drop until 1999. The period of 1990-1995 is a high violent period.
# Year fact can't affect the violent in logic, the change is other facts in these two lineplot.

# %% [markdown]
# # population fact

# %%
sns.scatterplot( data=a, x='population', y='violent')
# Out:
# <AxesSubplot:xlabel='population', ylabel='violent'>

# %% [markdown]
# In the scatterplot, we can know that the population can't affect violent. Some states which have low population have high violent, and high population states don't have high violent.

# %% [markdown]
# # density fact

# %%
sns.scatterplot( data=a, x='density', y='violent')
# Out:
# <AxesSubplot:xlabel='density', ylabel='violent'>

# %% [markdown]
# High density states have high violent and low density states usually have low states.
# Density fact also has relative high influence.

# %%
x1
# Out:
#       year  violent  murder  robbery  prisoners       afam      cauc  \
# 22    1999    490.2     7.9    121.2        519   9.331416  55.29781
# 45    1999    631.5     8.6     91.4        413   8.986603  60.55464
# 68    1999    551.2     8.0    152.5        507   4.343524  63.80436
# 91    1999    425.2     5.6     79.3        415   5.961927  61.21140
# 114   1999    627.2     6.0    181.1        483   8.089670  58.14976
# 137   1999    340.5     4.6     75.3        357   3.094968  71.19784
# 160   1999    345.6     3.3    123.5        372   4.480762  64.13895
# 183   1999    734.0     3.2    197.9        429   8.134692  58.07962
# 206   1999   1627.7    46.4    644.3       1913  21.669750  29.27457
# 229   1999    854.0     5.7    211.6        447   6.394272  57.11421
# 252   1999    534.0     7.5    166.4        502  11.108590  53.18856
# 275   1999    235.0     3.7     88.1        307  24.163870  26.08433
# 298   1999    244.9     2.0     17.8        330   1.250619  73.22482
# ...

# %%
x1.describe()
# Out:
#          year      violent     murder     robbery    prisoners       afam  \
# count    51.0    51.000000  51.000000   51.000000    51.000000  51.000000
# mean   1999.0   458.490196   5.868627  121.203922   396.647059   5.936082
# std       0.0   263.286718   6.279729   98.998315   257.770504   4.724273
# min    1999.0    66.900000   1.500000    8.800000   117.000000   0.710580
# 25%    1999.0   283.300000   2.950000   76.500000   273.000000   2.884523
# 50%    1999.0   411.900000   5.000000  101.100000   357.000000   4.507334
# 75%    1999.0   572.450000   7.050000  156.250000   452.000000   8.112181
# max    1999.0  1627.700000  46.400000  644.300000  1913.000000  24.163870
#
#             cauc       male  population        income    density
# count  51.000000  51.000000   51.000000     51.000000  51.000000
# mean   62.825890  14.196429    5.346879  16437.589216   0.339271
# std    10.030575   1.007038    5.985505   2607.155863   1.190835
# ...

# %% [markdown]
# # Can Law of control guns solve the Gun violence? Legislation at the federal, state, and local levels has attempted to address gun violence through a variety of methods.Is the way effective?

# %%
grouped = x1['law'].groupby(x1['violent'])

# display summary statistics for the groupings
grouped.describe()
# Out:
#         count unique  top freq
# violent
# 66.9        1      1  yes    1
# 96.5        1      1  yes    1
# 112.2       1      1  yes    1
# 113.8       1      1  yes    1
# 167.4       1      1  yes    1
# 206.5       1      1  yes    1
# 232.3       1      1  yes    1
# 235.0       1      1   no    1
# 244.9       1      1  yes    1
# 245.9       1      1   no    1
# 274.0       1      1   no    1
# 275.5       1      1  yes    1
# 280.0       1      1   no    1
# 286.6       1      1   no    1
# 300.6       1      1  yes    1
# 314.7       1      1  yes    1
# 316.4       1      1   no    1
# 340.5       1      1   no    1
# 345.6       1      1   no    1
# 349.3       1      1  yes    1
# 350.6       1      1  yes    1
# 374.6       1      1  yes    1
# 374.9       1      1  yes    1
# 377.3       1      1  yes    1
# 382.8       1      1   no    1
# 411.9       1      1   no    1
# 420.5       1      1  yes    1
# 425.2       1      1  yes    1
# 430.2       1      1   no    1
# ...

# %% [markdown]
# using grouped.describe to show the Law and state relationship from min violent to max violent.

# %%
a1=x1[['violent','density','state','law']]
a1
# Out:
#       violent   density                 state  law
# 22      490.2  0.086106               Alabama   no
# 45      631.5  0.001086                Alaska  yes
# 68      551.2  0.042047               Arizona  yes
# 91      425.2  0.048994              Arkansas  yes
# 114     627.2  0.212505            California   no
# 137     340.5  0.039103              Colorado   no
# 160     345.6  0.677406           Connecticut   no
# 183     734.0  0.385441              Delaware   no
# 206    1627.7  8.508196  District of Columbia   no
# 229     854.0  0.279853               Florida  yes
# 252     534.0  0.134468               Georgia  yes
# 275     235.0  0.184571                Hawaii   no
# 298     244.9  0.015126                 Idaho  yes
# 321     732.5  0.218164              Illinois   no
# 344     374.6  0.165679               Indiana  yes
# 367     280.0  0.051354                  Iowa   no
# 390     382.8  0.032437                Kansas   no
# ...

# %% [markdown]
# In this problem, it should consider the density fact.

# %%
#calculate violent number per 1 density
a2=a1['violent/density'] = a1['violent']/a1['density']
a2
# Out:
# <ipython-input-34-5811120416e4>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 22        5693.002902
# 45      581438.173281
# 68       13109.077418
# 91        8678.578281
# 114       2951.453021
# 137       8707.816320
# 160        510.181637
# 183       1904.310227
# 206        191.309650
# 229       3051.597729
# 252       3971.210952
# 275       1273.225530
# 298      16190.558042
# 321       3357.572024
# 344       2261.000043
# 367       5452.339735
# 390      11801.519893
# 413       3015.392949
# 436       7301.132089
# 459       2763.723785
# 482       1405.113714
# 505        699.371619
# 528       3311.054221
# 551       4568.113236
# 574       5918.854254
# 597       6302.240433
# 620      34048.376725
# ...

# %%
a2.describe()
# Out:
# count        51.000000
# mean      19596.751806
# std       81085.840829
# min         191.309650
# 25%        1858.720409
# 50%        4568.113236
# 75%        9550.779811
# max      581438.173281
# dtype: float64

# %%
a3=a1.loc[a1["state"]=='Ohio',]
a3
# Out:
#      violent   density state law  violent/density
# 827    316.4  0.274868  Ohio  no      1151.099657

# %%
a4=a1.loc[a1["state"]=='Florida',]
a4
# Out:
#      violent   density    state  law  violent/density
# 229    854.0  0.279853  Florida  yes      3051.597729

# %% [markdown]
# The max violent state is Alaska and it has low to control gun violent.
# The min violent state is District of Columbia and it doesn't have low to control gun violent.
# Two states Ohio and Florida have similar density, but the violent of Florida is more than Ohio a lot.
# Law of control violent can't reduce the violent effectivity in magic.

# %% [markdown]
# # conclusion

# %% [markdown]
# 1. Population and year can't affect the violent.
# Income, race and density facts can affect the violent.
# The influence of income is relative low, and race and density are highest facts in the data.
# 2. Low of gun violent can't reduce the violent effectivity in magic in the data.
