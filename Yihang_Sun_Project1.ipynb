# %% [markdown]
# Introduction
# Analyzing 3 problem
# #Which company have the most flights?
# #analyze distance ( distance choice)
# #analyzing the TaxiIN number for a week (CO company)   people perfer which day in a week?

# %% [raw]
# Data Preparation：reading the CSV file and name flight

# %%
import pandas as pd
import numpy as np

# supress scientific notation
np.set_printoptions(suppress = True)

# read the data file from GitHub and convert to a NumPy ndarray object
flight= pandas.read_csv('https://raw.githubusercontent.com/jtopor/DAV-5400/master/Project1/hflights.csv')

# verify you have an ndarray object
flight
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime UniqueCarrier  \
# 0      2011      1           1          6   1400.0   1500.0            AA
# 1      2011      1           2          7   1401.0   1501.0            AA
# 2      2011      1           3          1   1352.0   1502.0            AA
# 3      2011      1           4          2   1403.0   1513.0            AA
# 4      2011      1           5          3   1405.0   1507.0            AA
# ...     ...    ...         ...        ...      ...      ...           ...
# 19995  2011      2          25          5   1126.0   1333.0            CO
# 19996  2011      2          25          5    941.0   1111.0            CO
# 19997  2011      2          25          5    722.0    948.0            CO
# 19998  2011      2          25          5   1909.0   2216.0            CO
# 19999  2011      2          25          5   1255.0   1553.0            CO
#
#        FlightNum TailNum  ActualElapsedTime  ...  ArrDelay  DepDelay  Origin  \
# ...

# %%
#Which company have the most flights?
flight['UniqueCarrier'].describe()
# Out:
# count     20000
# unique       14
# top          CO
# freq       6830
# Name: UniqueCarrier, dtype: object

# %%
#analyze distance
flight['Distance'].describe()
# Out:
# count    20000.000000
# mean       772.899550
# std        458.640531
# min        127.000000
# 25%        351.000000
# 50%        787.000000
# 75%       1034.000000
# max       3904.000000
# Name: Distance, dtype: float64

# %%
flight['Distance'].plot(kind = 'hist')

# %%
#analyzing the TaxiIN number for a week (CO company)
fplot = flight[flight['UniqueCarrier'] == 'CO'].plot(x = 'DayOfWeek', y = 'TaxiIn')
